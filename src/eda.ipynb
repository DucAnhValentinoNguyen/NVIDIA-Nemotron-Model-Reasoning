# %% [markdown]
# ### EDA phase

# %%
#!pip install matplotlib pandas numpy IPython

import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd
import warnings

# Suppress librosa warnings about PySoundFile for mp3/ogg formats
warnings.filterwarnings('ignore')

# Set aesthetic defaults
plt.style.use('ggplot')
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Requirement already satisfied: pandas in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (3.0.1)
# Requirement already satisfied: numpy in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (2.4.3)
# Requirement already satisfied: IPython in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (9.11.0)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.62.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.5.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: packaging>=20.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: decorator>=5.1.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from IPython) (5.14.3)
# Requirement already satisfied: wcwidth in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->IPython) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->IPython) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from pexpect>4.6->IPython) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->IPython) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->IPython) (3.0.1)
# Requirement already satisfied: pure-eval in /home/duc/NVIDIA-Nemotron-Model-Reasoning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->IPython) (0.2.3)
# Using cached matplotlib-3.10.8-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.62.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
# Using cached kiwisolver-1.5.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached pillow-12.1.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [matplotlib]7 [matplotlib]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2

# %%
# Load the metadata
train_df = pd.read_csv("../data/train.csv")

print(f"Dim of dataset: {train_df.shape}")

# Let's look at the first few rows
display(train_df.head())
# Out:
# Dim of dataset: (9500, 3)
#          id                                             prompt  \
# 0  00066667  In Alice's Wonderland, a secret bit manipulati...
# 1  000b53cf  In Alice's Wonderland, a secret bit manipulati...
# 2  00189f6a  In Alice's Wonderland, secret encryption rules...
# 3  001b24c4  In Alice's Wonderland, numbers are secretly co...
# 4  001c63cb  In Alice's Wonderland, secret encryption rules...
#
#                   answer
# 0               10010111
# 1               01000011
# 2      cat imagines book
# 3                XXXVIII
# 4  wizard creates secret
